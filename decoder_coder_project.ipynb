# %%
#Message to decipher!

message = "xuo jxuhu! jxyi yi qd unqcfbu ev q squiqh syfxuh. muhu oek qrbu je tusetu yj? y xefu ie! iudt cu q cuiiqwu rqsa myjx jxu iqcu evviuj!"

# %%
import string

letters = list(string.ascii_lowercase)

# %%
def decoder(message, offset):
    new_message = ""
    for character in message:
        if character in letters:
            index = letters.index(character)
            #print(index)
            new_index = (index + offset) % 26
            #print(new_index)
            new_message = new_message + letters[new_index]
        else:
            pass
        if character == " ":
            new_message = new_message + " "
        else:
            pass
    return new_message

decoder("jxu evviuj veh jxu iusedt cuiiqwu yi vekhjuud.", 10)

x = range(26)
for i in x:
    print(str(i))
    print(decoder("vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx.",i))
# Out:
# 0
# vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx pxee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx
# 1
# wigjonylm bupy lyhxylyx uff iz nbymy ifx wcjbylm um ivmifyny qyff bupy ni lyuffs mnyj oj iol augy cz qy quhn ni eyyj iol gymmuaym muzy
# 2
# xjhkpozmn cvqz mziyzmzy vgg ja ocznz jgy xdkczmn vn jwnjgzoz rzgg cvqz oj mzvggt nozk pk jpm bvhz da rz rvio oj fzzk jpm hznnvbzn nvaz
# 3
# ykilqpano dwra najzanaz whh kb pdaoa khz yeldano wo kxokhapa sahh dwra pk nawhhu opal ql kqn cwia eb sa swjp pk gaal kqn iaoowcao owba
# 4
# zljmrqbop exsb obkaboba xii lc qebpb lia zfmebop xp lyplibqb tbii exsb ql obxiiv pqbm rm lro dxjb fc tb txkq ql hbbm lro jbppxdbp pxcb
# 5
# amknsrcpq fytc pclbcpcb yjj md rfcqc mjb agnfcpq yq mzqmjcrc ucjj fytc rm pcyjjw qrcn sn msp eykc gd uc uylr rm iccn msp kcqqyecq qydc
# 6
# bnlotsdqr gzud qdmcdqdc zkk ne sgdrd nkc bhogdqr zr narnkdsd vdkk gzud sn qdzkkx rsdo to ntq fzld he vd vzms sn jddo ntq ldrrzfdr rzed
# 7
# ...

# %%
#message_back = "hi this is my message back"

coded_message_back = ""

def coder(message, offset):
    for character in message:
        if character in letters:
            index = letters.index(character)
            new_index = (index - offset)
            if new_index < 0:
                new_index = new_index + 26
            new_message = new_message + letters[new_index]
        if character == " ":
            new_message = new_message + " "
    return(new_message)

# %%
#message = "txm srom vkda gl lzlgzr qpdb? fepb ejac! ubr imn tapludwy mhfbz cza ruxzal wg zztcgcexxch!"

#word = "friends"
#s = "friends"

#word = [i for i in s] 

#word_in_nums = []


#for i in word:
    #index = letters.index(i)
    #word_in_nums.append(index)
    
#new_message = ""

#index = 0

#for character in message:
   # if character in letters:
       # word[index]
        
        
#uncoded_message = ""

def decoder(message,key):
    word = [i for i in key]
    mod_message = ""

    count = 0
        
    for character in message:
    
        if character in letters: 
            mod_message = mod_message + word[count]
            count = (count + 1) % len(word)

        else:
            mod_message = mod_message + character
            
    #print(message)
    #print(mod_message)
            
    new_message = ""
    
    count_2 = 0

    for character in message:
        if character in letters:
            index = letters.index(character)
            mod_index = letters.index(mod_message[count_2])
            
            #print(mod_index)
            
            new_index = (index + mod_index) % 26
            
            new_message = new_message + letters[new_index]
            
            
            
            count_2 = count_2 + 1
            
        else:
            new_message = new_message + character
            
            count_2 = count_2 + 1
            
    return new_message
            
            
                
            
            
        
        
        
        
#index = letters.index(character) 
        
        
   # message.replace(word[i])
    
        
print(decoder("vqzhb! avug ef tm ysofhuq. vkj hfq mkh?","moment"))
# Out:
# hello! this is my message. how are you?

# %%
def coder(message,key):
    word = [i for i in key]
    mod_message = ""

    count = 0
        
    for character in message:
    
        if character in letters: 
            mod_message = mod_message + word[count]
            count = (count + 1) % len(word)

        else:
            mod_message = mod_message + character
            
    #print(message)
    #print(mod_message)
            
    new_message = ""
    
    count_2 = 0

    for character in message:
        if character in letters:
            index = letters.index(character)
            mod_index = letters.index(mod_message[count_2])
            
          #  print(mod_index)
            
            new_index = (index - mod_index) % 26
            
            new_message = new_message + letters[new_index]
            
            
            
            count_2 = count_2 + 1
            
        else:
            new_message = new_message + character
            
            count_2 = count_2 + 1
            
    return new_message

coder("hello! this is my message. how are you?", "moment")
# Out:
# 'vqzhb! avug ef tm ysofhuq. vkj hfq mkh?'

# %% [markdown]
# ##
